# %%
import requests
import urllib
import pandas as pd
from requests_html import HTML
from requests_html import HTMLSession

from bs4 import BeautifulSoup
import time

# %%
def get_source(url):
    """Return the source code for the provided URL. 
    Args: 
        url (string): URL of the page to scrape.
    Returns:
        response (object): HTTP response object from requests_html. 
    """
    time.sleep(5) # prevents captcha hopefully

    try:
        session = HTMLSession()
        response = session.get(url)
        return response

    except requests.exceptions.RequestException as e:
        print(e)

# %%
response = get_source("https://vhbonline.org/vhb4you/vhb-jourqual/vhb-jourqual-3/gesamtliste")
soup = BeautifulSoup(response.html.raw_html)

# %%
# Out:
# 3548

# %%
table = soup.find("tbody")
table_content = [x.text.strip() for x in table.find_all("td")]

journal_titles = []
issn_numbers = []
jq3_ratings = []
in_partial_rankings = []

for i in range (0, len(table_content), 4):
    journal_titles.append(table_content[i])
    issn_numbers.append(table_content[i+1])
    jq3_ratings.append(table_content[i+2])
    in_partial_rankings.append(table_content[i+3])

# %%
data = {'JOURNAL': journal_titles, 
        'ISSN': issn_numbers, 
        'JQ3': jq3_ratings,  
        'IN_PARTIAL_RANKING': in_partial_rankings
       }

pd.DataFrame(data)
# Out:
#                                                JOURNAL       ISSN     JQ3  \
# 0                                                  4OR  1619-4500       C
# 1                                               Abacus  0001-3072       B
# 2                                     Absatzwirtschaft  0001-3374  k.w.Z.
# 3                         Academy of Management Annals  1941-6520       A
# 4                  Academy of Management Journal (AMJ)  0001-4273      A+
# ..                                                 ...        ...     ...
# 882  ZfU - Zeitschrift für Umweltpolitik & Umweltrecht  0931-0983       B
# 883             ZIÖ Zeitschrift für Immobilienökonomie  1611-4051       C
# 884  ZögU: Zeitschrift für öffentliche und gemeinwi...  0344-9777       C
# 885  ZSteu: Zeitschrift für Steuern & Recht (einges...  1614-7936  k.w.Z.
# 886  ZWF - Zeitschrift für wirtschaftlichen Fabrikb...  0947-0085    k.R.
#
#     IN_PARTIAL_RANKING
# 0                   OR
# 1    BA-FI, STEU, RECH
# 2                 MARK
# 3                 ABWL
# 4                 ABWL
# ..                 ...
# 882               NAMA
# 883               ABWL
# 884               ÖBWL
# 885               STEU
# 886               PROD
#
# [887 rows x 4 columns]
