# %%
# change to store dataset
STORE_VHB = False

# %%
import requests
import urllib
import pandas as pd
from requests_html import HTML
from requests_html import HTMLSession

from bs4 import BeautifulSoup
import time

# %%
def get_source(url):
    """Return the source code for the provided URL. 
    Args: 
        url (string): URL of the page to scrape.
    Returns:
        response (object): HTTP response object from requests_html. 
    """
    time.sleep(5) # prevents captcha hopefully

    try:
        session = HTMLSession()
        response = session.get(url)
        return response

    except requests.exceptions.RequestException as e:
        print(e)

# %% [markdown]
# # VHB

# %%
# get website content
response = get_source("https://vhbonline.org/vhb4you/vhb-jourqual/vhb-jourqual-3/gesamtliste")
soup = BeautifulSoup(response.html.raw_html)

# %%
# get table content
table = soup.find("tbody")
table_content = [x.text.strip() for x in table.find_all("td")]

journal_titles = []
issn_numbers = []
jq3_ratings = []
in_partial_rankings = []

# loop over table and add to according list
for i in range (0, len(table_content), 4):
    journal_titles.append(table_content[i])
    issn_numbers.append(table_content[i+1])
    jq3_ratings.append(table_content[i+2])
    in_partial_rankings.append(table_content[i+3])

# %%
# create dataframe
data = {'JOURNAL': journal_titles, 
        'ISSN': issn_numbers, 
        'JQ3': jq3_ratings,  
        'IN_PARTIAL_RANKING': in_partial_rankings
       }

journal_ratings_from_vhb = pd.DataFrame(data)

# %%
if STORE_VHB:
    journal_ratings_from_vhb.to_csv('data/journal_ratings_from_vhb.csv')

# %% [markdown]
# # Scimago

# %%
# get first page content
response = get_source("https://www.scimagojr.com/journalrank.php?type=j&page=1")
soup = BeautifulSoup(response.html.raw_html)

# %%
#number_of_pages = int(soup.find("div", class_="pagination").text.split(" ")[-1])
#for testing:
number_of_pages = 3

# %%
table = soup.find("tbody")
journal_titles = [x.text.strip() for x in table.find_all("td", class_="tit")]
sjr_ratings = [x.text.replace(x.find("span").text, "").strip() for x in table.find_all("td", class_="orde")]
h_index_ratings = [x.text.strip() for x in table.find_all("td", class_=None)]
h_index_ratings
# Out:
# ['51',
#  'journal',
#  '160',
#  '21',
#  '89',
#  '3698',
#  '887',
#  '89',
#  '8.66',
#  '176.10',
#  '',
#  '52',
#  'journal',
#  '262',
#  '29',
#  '79',
#  '4986',
#  '2059',
#  '79',
#  '25.28',
#  '171.93',
#  '',
#  '53',
#  'journal',
#  '256',
#  '154',
#  '373',
#  '7975',
#  '3129',
#  '372',
#  '6.88',
#  '51.79',
#  '',
#  '54',
#  'journal',
#  '413',
#  '156',
#  '416',
#  '8018',
#  '5687',
#  '253',
#  '11.48',
#  '51.40',
#  '',
#  '55',
#  'journal',
#  '91',
#  '4',
#  '20',
#  '1722',
#  '1261',
#  '20',
#  '73.77',
#  '430.50',
#  '',
#  '56',
#  'journal',
#  '300',
#  '169',
#  '488',
#  '7828',
#  '8929',
#  '299',
#  '18.33',
#  '46.32',
#  '',
#  '57',
#  'journal',
#  '369',
#  '163',
#  '570',
#  '7384',
#  '8897',
#  '474',
#  '15.81',
#  '45.30',
#  '',
#  '58',
#  'journal',
#  '318',
#  '68',
#  '261',
#  '6929',
#  '2839',
#  '260',
#  '9.13',
#  '101.90',
#  '',
#  '59',
#  'journal',
#  '220',
#  '23',
#  '80',
#  '3751',
#  '1274',
#  '77',
#  '12.61',
#  '163.09',
#  '',
#  '60',
#  'journal',
#  '286',
#  '120',
#  '378',
#  '9598',
#  '3648',
#  '368',
#  '8.24',
#  '79.98',
#  '',
#  '61',
#  'journal',
#  '183',
#  '24',
#  '71',
#  '3613',
#  '1117',
#  '71',
#  '16.02',
#  '150.54',
#  '',
#  '62',
#  'journal',
#  '72',
#  '7',
#  '19',
#  '2701',
#  '879',
#  '19',
#  '50.43',
#  '385.86',
#  '',
#  '63',
#  'journal',
#  '313',
#  '33',
#  '136',
#  '5265',
#  '3042',
#  '123',
#  '13.90',
#  '159.55',
#  '',
#  '64',
#  'journal',
#  '95',
#  '101',
#  '253',
#  '9555',
#  '6999',
#  '179',
#  '19.15',
#  '94.60',
#  '',
#  '65',
#  'journal',
#  '527',
#  '1509',
#  '4195',
#  '129070',
#  '118321',
#  '4161',
#  '27.23',
#  '85.53',
#  '',
#  '66',
#  'journal',
#  '548',
#  '583',
#  '1890',
#  '17448',
#  '23642',
#  '1221',
#  '12.29',
#  '29.93',
#  '',
#  '67',
#  'journal',
#  '207',
#  '23',
#  '71',
#  '3350',
#  '1688',
#  '71',
#  '18.39',
#  '145.65',
#  '',
#  '68',
#  'journal',
#  '61',
#  '30',
#  '104',
#  '1328',
#  '523',
#  '104',
#  '4.63',
#  '44.27',
#  '',
#  '69',
#  'journal',
#  '243',
#  '26',
#  '79',
#  '3844',
#  '1920',
#  '76',
#  '22.09',
#  '147.85',
#  '',
#  '70',
#  'journal',
#  '266',
#  '215',
#  '693',
#  '12016',
#  '12515',
#  '661',
#  '17.38',
#  '55.89',
#  '',
#  '71',
#  'journal',
#  '431',
#  '935',
#  '2960',
#  '22363',
#  '23475',
#  '1191',
#  '7.44',
#  '23.92',
#  '',
#  '72',
#  'journal',
#  '241',
#  '24',
#  '76',
#  '3557',
#  '1228',
#  '76',
#  '12.47',
#  '148.21',
#  '',
#  '73',
#  'journal',
#  '29',
#  '115',
#  '105',
#  '6032',
#  '1953',
#  '55',
#  '18.60',
#  '52.45',
#  '',
#  '74',
#  'journal',
#  '220',
#  '725',
#  '1978',
#  '63843',
#  '52484',
#  '1966',
#  '26.52',
#  '88.06',
#  '',
#  '75',
#  'journal',
#  '232',
#  '203',
#  '635',
#  '7471',
#  '9958',
#  '525',
#  '15.26',
#  '36.80',
#  '',
#  '76',
#  'journal',
#  '328',
#  '247',
#  '676',
#  '7946',
#  '8550',
#  '314',
#  '12.38',
#  '32.17',
#  '',
#  '77',
#  'journal',
#  '48',
#  '21',
#  '60',
#  '2572',
#  '1151',
#  '57',
#  '16.45',
#  '122.48',
#  '',
#  '78',
#  'journal',
#  '216',
#  '502',
#  '1501',
#  '7656',
#  '10533',
#  '538',
#  '6.36',
#  '15.25',
#  '',
#  '79',
#  'journal',
#  '156',
#  '15',
#  '45',
#  '2460',
#  '794',
#  '44',
#  '17.48',
#  '164.00',
#  '',
#  '80',
#  'journal',
#  '196',
#  '41',
#  '140',
#  '2515',
#  '1972',
#  '138',
#  '8.10',
#  '61.34',
#  '',
#  '81',
#  'journal',
#  '473',
#  '415',
#  '1456',
#  '25049',
#  '18448',
#  '1435',
#  '11.37',
#  '60.36',
#  '',
#  '82',
#  'journal',
#  '47',
#  '159',
#  '323',
#  '4639',
#  '4033',
#  '172',
#  '12.49',
#  '29.18',
#  '',
#  '83',
#  'journal',
#  '297',
#  '159',
#  '534',
#  '9436',
#  '6386',
#  '530',
#  '8.79',
#  '59.35',
#  '',
#  '84',
#  'journal',
#  '270',
#  '165',
#  '488',
#  '7527',
#  '4986',
#  '441',
#  '10.51',
#  '45.62',
#  '',
#  '85',
#  'journal',
#  '122',
#  '20',
#  '56',
#  '2953',
#  '1260',
#  '56',
#  '21.69',
#  '147.65',
#  '',
#  '86',
#  'journal',
#  '21',
#  '2',
#  '3',
#  '186',
#  '33',
#  '3',
#  '0.00',
#  '93.00',
#  '',
#  '87',
#  'journal',
#  '282',
#  '37',
#  '104',
#  '10963',
#  '2820',
#  '103',
#  '24.43',
#  '296.30',
#  '',
#  '88',
#  'journal',
#  '175',
#  '55',
#  '154',
#  '18579',
#  '6060',
#  '154',
#  '39.67',
#  '337.80',
#  '',
#  '89',
#  'journal',
#  '309',
#  '305',
#  '937',
#  '8232',
#  '16763',
#  '531',
#  '15.22',
#  '26.99',
#  '',
#  '90',
#  'journal',
#  '159',
#  '15',
#  '77',
#  '2037',
#  '1212',
#  '77',
#  '13.70',
#  '135.80',
#  '',
#  '91',
#  'journal',
#  '388',
#  '249',
#  '749',
#  '8257',
#  '8095',
#  '591',
#  '10.00',
#  '33.16',
#  '',
#  '92',
#  'journal',
#  '113',
#  '330',
#  '813',
#  '5300',
#  '5271',
#  '247',
#  '6.76',
#  '16.06',
#  '',
#  '93',
#  'journal',
#  '248',
#  '296',
#  '741',
#  '19556',
#  '9017',
#  '699',
#  '11.71',
#  '66.07',
#  '',
#  '94',
#  'journal',
#  '537',
#  '1119',
#  '3970',
#  '64745',
#  '60949',
#  '3963',
#  '16.48',
#  '57.86',
#  '',
#  '95',
#  'journal',
#  '165',
#  '62',
#  '193',
#  '2927',
#  '1321',
#  '193',
#  '6.75',
#  '47.21',
#  '',
#  '96',
#  'journal',
#  '179',
#  '45',
#  '188',
#  '2621',
#  '1537',
#  '186',
#  '6.69',
#  '58.24',
#  '',
#  '97',
#  'journal',
#  '248',
#  '189',
#  '600',
#  '9573',
#  '7913',
#  '545',
#  '13.08',
#  '50.65',
#  '',
#  '98',
#  'journal',
#  '72',
#  '39',
#  '81',
#  '0',
#  '1351',
#  '81',
#  '10.29',
#  '0.00',
#  '',
#  '99',
#  'journal',
#  '99',
#  '429',
#  '1314',
#  '5903',
#  '11688',
#  '633',
#  '8.24',
#  '13.76',
#  '',
#  '100',
#  'journal',
#  '51',
#  '133',
#  '322',
#  '5313',
#  '3498',
#  '298',
#  '10.73',
#  '39.95',
#  '']

# %%
for page_number in range(1,number_of_pages):
    response = get_source(f"https://www.scimagojr.com/journalrank.php?type=j&page={page_number}")
    soup = BeautifulSoup(response.html.raw_html)
    print(soup.find("div", class_="pagination").text)
# Out:
# 1 - 50 of 25231
# 51 - 100 of 25231
