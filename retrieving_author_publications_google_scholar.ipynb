# %%
#%pip install requests_html

# %%
import requests
import urllib
import pandas as pd
from requests_html import HTML
from requests_html import HTMLSession

from bs4 import BeautifulSoup
import re
import time
# Out:
# C:\Users\katma\anaconda3\lib\site-packages\requests\__init__.py:78: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({0}) or chardet ({1}) doesn't match a supported "

# %%
def get_source(url):
    """Return the source code for the provided URL. 
    Args: 
        url (string): URL of the page to scrape.
    Returns:
        response (object): HTTP response object from requests_html. 
    """
    time.sleep(3)

    try:
        session = HTMLSession()
        response = session.get(url)
        return response

    except requests.exceptions.RequestException as e:
        print(e)

# %%
def get_author_id_query(author_name):
    
    # get HTML response for author
    query = urllib.parse.quote_plus(author_name)
    response = get_source("https://scholar.google.com/scholar?q=" + query)
    soup = BeautifulSoup(response.html.raw_html)
    
    if soup.find("h4", class_ = "gs_rt2"): # check if is profile
        # get user ID for query
        query_with_id = soup.find("h4", class_ = "gs_rt2").find("a").get('href')
        
    else:
        query_with_id = None
        print(f"{author_name} does not have a profile on Google Scholar.")
        
    return query_with_id

# %%
def get_author_profile(author_name):
    
    query_with_id = get_author_id_query(author_name)
    
    # get HTML response for author profile
    response = get_source(f"https://scholar.google.com{query_with_id}&cstart=0&pagesize=1001") # the last part is to get all entries
    
    if response:
        soup = BeautifulSoup(response.html.raw_html)
    else:
        soup = None
    
    return soup

# %%
def get_all_publication_entries(author_name):
    
    soup = get_author_profile(author_name)
    
    if soup:
        #get article entries
        all_article_entries = soup.find_all("tr", class_ = "gsc_a_tr")
        
    else:
        all_article_entries = None
        
    return all_article_entries

# %%
def get_publication_info(entry):
    
    publication_title = ""
    publication_year = ""
    authors_list = []
    number_citations = ""
    
    # get authors and journal
    if entry.find("div", class_ = "gs_gray"):
        string_with_authors = entry.find("div", class_ = "gs_gray").string
        authors_list = string_with_authors.split(",")
        
        publisher_string = entry.find_all("div", class_ = "gs_gray")[1].text
        publisher = publisher_string.split(",")[0] #also has ISBN

    # get title
    if entry.find("a", class_="gsc_a_at"):
        publication_title = entry.find("a", class_="gsc_a_at").string

    # get year
    if entry.find("span", class_ = "gsc_a_h gsc_a_hc gs_ibl"):
        publication_year = entry.find("span", class_ = "gsc_a_h gsc_a_hc gs_ibl").string

    # get number of citations
    if entry.find("a", class_ = "gsc_a_ac gs_ibl"):
        number_citations = entry.find("a", class_ = "gsc_a_ac gs_ibl").string
        
    
    
    return publication_title, publication_year, authors_list, number_citations, publisher

# %%
def get_dataframe_with_publications(author_name):
    
    publication_titles = []
    publication_years = []
    publishers = []
    authors_lists = []
    number_citations_list = []
    author_name_list = []
    
    all_publication_entries = get_all_publication_entries(author_name)
    
    if all_publication_entries:
        
        for publication_entry in all_publication_entries:
            publication_title, publication_year, authors_list, number_citations, publisher = get_publication_info(publication_entry)

            publication_titles.append(publication_title)
            publication_years.append(publication_year)
            publishers.append(publisher)
            authors_lists.append(authors_list)
            number_citations_list.append(number_citations)
            author_name_list.append(author_name)


    data = {'PUB_TITLE': publication_titles, 
            'PUB_YEAR': publication_years,
            'PUB_PUBLISHER': publishers,
            'PUB_AUTHORS': authors_lists, 
            'PUB_CITATIONS': number_citations_list, 
            'AUTHOR_NAME': author_name_list}
    
    return pd.DataFrame(data)

# %%
get_dataframe_with_publications("Stephan Daurer")
# Out:
#                                             PUB_TITLE PUB_YEAR  \
# 0   Einführung in die Wirtschaftsinformatik: Ein f...     2021
# 1   Digitalisierung und Konvergenz von Online-und ...     2012
# 2   Consumer Search Behavior on the Mobile Interne...     2016
# 3   Assistive technology for independent living wi...     2018
# 4   Tell Me Where You Are and I’ll Tell You What Y...     2016
# 5   Measuring Individual Search Costs on the Mobil...     2012
# 6   Potenziale integrierter Social Software-das Be...     2006
# 7   The Impact of Smartphones, Barcode Scanning, a...     2013
# 8   Parental control reversed: Using ADR for desig...     2017
# 9   Consumer Preferences for Product Information a...     2017
# 10  iCare—supporting people with increased need fo...     2016
# 11  iCare – Supporting People with Increased Need ...     2016
# 12  iCare–Do-It-Yourself: Architektur ambienter As...     2017
# 13  Application of Media Synchronicity Theory to C...     2019
# 14  Chatbots as a User Interface for Assistive Tec...     2018
# 15  Do‐It‐Yourself as a Means for Making Assistive...     2021
# 16                     Die Aufklärung und das Web 2.0     2019
# 17  Digitizing Offline Search: An Empirical Analys...     2018
# 18  Notfallerkennung mit ambienten Assistenzsystem...     2017
# 19  Sag mir, wo du bist und ich sage dir, was du w...     2016
# 20                    Adblocker: Bitte keine Werbung!     2016
# 21                                          Adblocker     2016
# 22  Location-based Services and Consumer Search on...     2014
# 23                                       IT-Strategie     2013
# 24             Einkauf durch mobile Suche im Internet     2013
#
#                                         PUB_PUBLISHER  \
# 0                               De Gruyter Oldenbourg
# 1     Zeitschrift für Betriebswirtschaft (ZfB) 82 (4)
# 2                       Ross School of Business Paper
# 3                  Health Policy and Technology 7 (1)
# 4             GfK Marketing Intelligence Review 8 (2)
# 5                                                ECIS
# 6            HMD-Praxis der Wirtschaftsinformatik 252
# 7
# 8                               ICIS 2017 Proceedings
# 9   Proceedings of the 13th International Conferen...
# 10  European Journal of Epidemiology 31 (1 (Supple...
# 11  Health – Exploring Complexity: An Interdiscipl...
# 12            Smart-Future-Living-Bodensee Conference
# 13  Proceedings of the 14th International Conferen...
# 14  Assistenztechnologien in der Arbeitswelt. Beit...
# 15                        Information Systems Journal
# 16  Wirtschaftsinformatik und Management. DOI: 10....
# 17                      Ross School of Business Paper
# 18                                 Usability Day XV 1
# 19  GfK MIR - Marketingforschung für die Praxis 8 (2)
# 20  Markenartikel – Fachmagazin für Markenführung ...
# 21  MedienWirtschaft - Zeitschrift für Medienmanag...
# 22                                             epubli
# 23  IT für Existenzgründer und junge Unternehmen -...
# 24            WISU - Das Wirtschaftsstudium 2013 (11)
#
#                                        PUB_AUTHORS PUB_CITATIONS  \
# 0                  [MA Bächle,  S Daurer,  A Kolb]            38
# 1                 [S Daurer,  D Molitor,  M Spann]            22
# 2   [S Daurer,  D Molitor,  M Spann,  P Manchanda]            20
# 3       [M Bächle,  S Daurer,  A Judt,  T Mettler]            19
# 4                 [M Spann,  D Molitor,  S Daurer]            14
# 5                 [S Daurer,  D Molitor,  M Spann]            13
# 6                            [M Bächle,  S Daurer]            11
# 7   [S Daurer,  D Molitor,  M Spann,  P Manchanda]             9
# 8       [T Mettler,  M Bächle,  S Daurer,  A Judt]             4
# 9                 [J Fölting,  S Daurer,  M Spann]             4
# 10      [M Bächle,  S Daurer,  A Judt,  T Mettler]             3
# 11      [M BÄCHLE,  S DAURER,  A JUDT,  T METTLER]
# 12      [A Judt,  M Bächle,  S Daurer,  T Mettler]             2
# 13                         [L Furmanek,  S Daurer]             1
# 14      [M Bächle,  S Daurer,  A Judt,  T Mettler]             1
# 15     [T Mettler,  S Daurer,  MA Bächle,  A Judt]          None
# 16                          [MA Bächle,  S Daurer]          None
# 17  [D Molitor,  S Daurer,  M Spann,  P Manchanda]          None
# 18      [M Bächle,  S Daurer,  A Judt,  T Mettler]          None
# 19                [M Spann,  D Molitor,  S Daurer]          None
# 20                            [T Krohn,  S Daurer]          None
# 21                            [S Daurer,  T Krohn]          None
# 22                                      [S Daurer]          None
# 23                                      [S Daurer]          None
# 24                [M Spann,  S Daurer,  D Molitor]          None
#
#        AUTHOR_NAME
# 0   Stephan Daurer
# 1   Stephan Daurer
# 2   Stephan Daurer
# 3   Stephan Daurer
# 4   Stephan Daurer
# 5   Stephan Daurer
# 6   Stephan Daurer
# 7   Stephan Daurer
# 8   Stephan Daurer
# 9   Stephan Daurer
# 10  Stephan Daurer
# 11  Stephan Daurer
# 12  Stephan Daurer
# 13  Stephan Daurer
# 14  Stephan Daurer
# 15  Stephan Daurer
# 16  Stephan Daurer
# 17  Stephan Daurer
# 18  Stephan Daurer
# 19  Stephan Daurer
# 20  Stephan Daurer
# 21  Stephan Daurer
# 22  Stephan Daurer
# 23  Stephan Daurer
# 24  Stephan Daurer

# %% [raw]
# Problem:
# - Not all authors have an account
# -> need to keep track of those who don't
# - publisher is not fucking einheitlich
